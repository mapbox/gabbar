# %% [markdown]
# # Clean data from OSMCha

# %%
import pandas as pd

# %%
# Download changesets from osmcha as a csv file.
changesets = pd.read_csv('http://osmcha.mapbox.com/?date__gte=2017-01-01&date__lte=2017-04-30&is_suspect=False&is_whitelisted=All&harmful=None&checked=True&all_reason=True&render_csv=True')
changesets.head()
# Out:
#          ID                  user             editor Powerfull Editor  \
# 0  48269913  Julio_Costa_Zambelli           iD 2.1.3            False
# 1  48269889                Dangoh           iD 2.1.3            False
# 2  48269805                   강상미  MAPS.ME ios 7.2.4            False
# 3  48269788                Fluous           iD 2.1.3            False
# 4  48269784           MasterC0329       Go Map!! 1.4            False
#
#                                              comment        source  \
# 0  Elimina nodo place=city denominado "Cabo de Ho...  Not reported
# 1  Localidade sem denominação. Inclusão de ruas e...  Not reported
# 2                                                NaN  Not reported
# 3                                     Added features  Not reported
# 4                            Adding a park in Avilla  Not reported
#
#                                        imagery used  \
# 0                               Bing aerial imagery
# 1  Bing aerial imagery;IBGE Mapa de Setores Urbanos
# 2                                      Not reported
# 3                               Bing aerial imagery
# 4                                      Not reported
#
#                         date  reasons                     reasons__name  \
# 0  2017-04-29T23:59:10+00:00     64.0                 City/town deleted
# 1  2017-04-29T23:56:38+00:00      NaN                               NaN
# 2  2017-04-29T23:48:00+00:00     47.0  Large building added by new user
# 3  2017-04-29T23:45:53+00:00      NaN                               NaN
# 4  2017-04-29T23:45:13+00:00     44.0            Park added by new user
#
#    create  modify  delete                                               bbox  \
# 0     0.0     0.0     1.0  SRID=4326;POLYGON ((-67.6186818 -54.9324528, -...
# 1   439.0     3.0     0.0  SRID=4326;POLYGON ((-42.3044933 -20.6087278, -...
# 2     0.0     1.0     0.0  SRID=4326;POLYGON ((116.072243 5.9824075, 116....
# 3    35.0    23.0    17.0  SRID=4326;POLYGON ((-75.70313590000001 41.4205...
# 4    14.0     0.0     0.0  SRID=4326;POLYGON ((-81.3884748 30.0113143, -8...
#
#   is suspect harmful checked check_user__username  \
# 0       True   False    True            dannykath
# 1      False   False    True             Skippern
# 2      False   False    True      nikhilprabhakar
# 3      False   False    True         Chetan_Gowda
# 4      False   False    True            Luis36995
#
#                          check date harmful_reasons__name
# 0  2017-05-16T15:55:45.542874+00:00                   NaN
# 1  2017-05-03T01:07:29.136324+00:00                   NaN
# 2  2017-05-02T07:16:23.454699+00:00                   NaN
# 3  2017-04-30T04:39:44.342262+00:00                   NaN
# 4  2017-05-03T18:55:03.215073+00:00                   NaN

# %%
# Filter only changesets that have only one feature modified.
changesets = changesets[
    (changesets['create'] <= 0) &
    (changesets['modify'] == 1) &
    (changesets['delete'] <= 0)
]

# %%
# Remove duplicates by changeset ID.
print('Before removing duplicated: {}'.format(changesets.shape[0]))
changesets = changesets.drop_duplicates(subset='ID')
print('After removing duplicated: {}'.format(changesets.shape[0]))
# Out:
# Before removing duplicated: 10383
# After removing duplicated: 9728

# %%
# Write back filtered changesets to a file.
changesets.to_csv('../downloads/changesets-filtered.csv', index=False)
